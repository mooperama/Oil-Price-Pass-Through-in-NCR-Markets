# %% [markdown]
# # [Mini Project Title]

# %% [markdown]
# -> Recommended content provided by ***ChatGPT***

# %% [markdown]
# ## 1 Executive Summary

# %% [markdown]
# Provide a high-level overview of the entire project.
#
# Include:
#
# - The problem being addressed
# - Data sources used
# - Brief description of methodology
# - Key findings
# - Main recommendation
#
# Keep it concise (1–2 paragraphs).

# %% [markdown]
# ## 2 Introduction

# %% [markdown]
# Provide context and clearly define the problem.
#
# Include:
#
# - Background of the problem or use case
# - Why the problem is relevant
# - Clearly stated project objective
# - Scope and limitations (if any)

# %% [markdown]
# ## 3 Business Value

# %% [markdown]
# Justify why this project matters.
#
# Explain:
# - Who benefits from this analysis?
# - What decisions can be improved using your insights?
# - What risks, opportunities, or inefficiencies does this address?
# - How can your findings create measurable value (e.g., cost savings, revenue growth, better decision-making)?

# %% [markdown]
# ## 4 Data

# %% [markdown]
# Describe the data sources and structure.
#
# Include:
#
# - Data sources (API, website, etc.)
# - How the data was collected (brief explanation)
# - Number of records and key variables
# - Data format (CSV, JSON, database, etc.)
# - Data quality issues encountered (missing values, inconsistencies, duplicates)

# %% [markdown]
# ## 5 Methodology

# %% [markdown]
# Explain what you did to prepare and analyze the data.
#
# Include:
#
# - Data cleaning steps
# - Data transformation and feature engineering
# - Merging or aggregation processes
# - Analytical techniques used (e.g., grouping, trend analysis, correlation, simple modeling)

# %% [markdown]
# ## 6 Results and Discussion

# %% [markdown]
# Present findings and interpret them.
#
# Include:
#
# - Key visualizations
# - Important trends or patterns discovered
# - Statistical summaries (if relevant)
# - Interpretation of results in business terms

# %% [markdown]
# ## 7 Conclusion

# %% [markdown]
# Summarize the main insights.
#
# Include:
#
# - Restatement of the objective
# - Summary of key findings
# - Overall takeaway message
#
# Keep it concise and focused.

# %% [markdown]
# ## 8 Recommendation

# %% [markdown]
# Provide actionable suggestions based on your findings.
#
# Include:
#
# - Specific actions stakeholders should take
# - Justification based on your analysis
# - Short-term vs. long-term suggestions (if applicable)
#
# Recommendations must be directly supported by your results.

# %% [markdown]
# ## References

# %% [markdown]
# Properly credit data sources and external materials.
#
# Include:
#
# - APIs used
# - Websites scraped
# - Documentation referenced
# - External articles or reports cited
#
# Use a consistent citation format.

# %% [markdown]
# ## Acknowledgements

# %% [markdown]
# Recognize contributions and support.
